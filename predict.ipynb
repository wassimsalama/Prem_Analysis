# %%
import pandas as pd

matches = pd.read_csv("matches.csv",index_col = 0)

matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1.0  0.0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#    season     team
# 1    2023  Arsenal
# 2    2023  Arsenal
# 3    2023  Arsenal
# 4    2023  Arsenal
# 5    2023  Arsenal
#
# [5 rows x 27 columns]

# %%
matches["team"].value_counts()
# Out:
# team
# Crystal Palace              132
# Brighton and Hove Albion    132
# Aston Villa                 132
# Arsenal                     131
# Liverpool                   131
# Manchester City             131
# Tottenham Hotspur           131
# Newcastle United            131
# Manchester United           131
# West Ham United             131
# Chelsea                     131
# Everton                     131
# Wolverhampton Wanderers     131
# Southampton                 114
# Leicester City              114
# Leeds United                114
# Brentford                    93
# Burnley                      93
# Fulham                       93
# Sheffield United             56
# Nottingham Forest            55
# Bournemouth                  54
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Luton Town                   16
# Name: count, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     80
# Matchweek 10    80
# Matchweek 2     80
# Matchweek 16    80
# Matchweek 15    80
# Matchweek 13    80
# Matchweek 12    80
# Matchweek 11    80
# Matchweek 14    80
# Matchweek 9     80
# Matchweek 7     80
# Matchweek 6     80
# Matchweek 5     80
# Matchweek 4     80
# Matchweek 8     80
# Matchweek 3     80
# Matchweek 17    78
# Matchweek 18    64
# Matchweek 35    60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 28    60
# Matchweek 32    60
# Matchweek 36    60
# Matchweek 37    60
# Matchweek 30    60
# Matchweek 31    60
# Matchweek 20    60
# Matchweek 29    60
# Matchweek 27    60
# Matchweek 26    60
# Matchweek 25    60
# Matchweek 24    60
# Matchweek 23    60
# Matchweek 22    60
# Matchweek 21    60
# Matchweek 19    60
# Matchweek 38    60
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date'])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+","",regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches["target"]=(matches["result"]=='W').astype("int")
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W  2.0
# 2  2023-08-21  20:00  Premier League   Matchweek 2  Mon  Away      W  1.0
# 3  2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D  2.0
# 4  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3.0
# 5  2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga         opponent  ...   fk  pk  pkatt  season              team  \
# 1   1.0  Nott'ham Forest  ...  0.0   0      0    2023           Arsenal
# 2   0.0   Crystal Palace  ...  0.0   1      1    2023           Arsenal
# 3   2.0           Fulham  ...  0.0   1      1    2023           Arsenal
# 4   1.0   Manchester Utd  ...  0.0   0      0    2023           Arsenal
# 5   0.0          Everton  ...  0.0   0      0    2023           Arsenal
# ..  ...              ...  ...  ...  ..    ...     ...               ...
# 38  4.0        Tottenham  ...  0.0   0      0    2020  Sheffield United
# 39  2.0   Crystal Palace  ...  1.0   0      0    2020  Sheffield United
# 40  0.0          Everton  ...  0.0   0      0    2020  Sheffield United
# 41  1.0    Newcastle Utd  ...  1.0   0      0    2020  Sheffield United
# 42  0.0          Burnley  ...  0.0   0      0    2020  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 1           1       18   12         5       1
# 2           0        7   20         0       1
# 3           1        9   15         5       0
# 4           1       15   16         6       1
# 5           0        8   16         6       1
# ..        ...      ...  ...       ...     ...
# 38          0       21   19         6       0
# 39          1        7   15         5       0
# 40          0        8   19         6       1
# 41          0       16   18         2       0
# 42          1        5   16         6       1
#
# [2622 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

train = matches[matches["date"] < '2023-01-01']

test = matches[matches["date"] > '2023-01-01']

predictors = ["venue_code", "opp_code", "hour", "day_code"]

rf.fit(train[predictors], train["target"])

RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

preds = rf.predict(test[predictors])

from sklearn.metrics import accuracy_score

error = accuracy_score(test["target"], preds)

error
# Out:
# 0.6064935064935065

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          370  99
# 1          204  97

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.49489795918367346

# %%
grouped_matches = matches.groupby("team")

group = grouped_matches.get_group("Manchester City").sort_values("date")

def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 5   0.0         Arsenal  ...         5       1    2.000000    2.333333
# 7   1.0        West Ham  ...         5       0    1.333333    2.000000
# 9   0.0   Sheffield Utd  ...         5       1    1.000000    0.666667
# 11  1.0       Liverpool  ...         6       0    1.000000    0.333333
# 12  2.0       Tottenham  ...         5       0    1.000000    0.666667
# ..  ...             ...  ...       ...     ...         ...         ...
# 19  1.0       Liverpool  ...         5       0    4.333333    1.666667
# 21  3.0       Tottenham  ...         6       0    3.666667    2.000000
# 22  1.0     Aston Villa  ...         2       0    2.666667    2.666667
# 23  1.0      Luton Town  ...         6       1    1.333333    1.666667
# 25  2.0  Crystal Palace  ...         5       0    1.666667    1.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 5   17.333333    4.666667    19.700000   1.333333    0.333333       0.333333
# 7   17.333333    3.666667    18.566667   0.666667    0.000000       0.000000
# 9   16.666667    4.333333    18.933333   0.666667    0.000000       0.000000
# 11  14.333333    6.666667    19.033333   1.000000    0.000000       0.000000
# 12  12.000000    5.666667    20.000000   1.000000    0.000000       0.333333
# ..        ...         ...          ...        ...         ...            ...
# 19  18.333333    8.666667    16.733333   1.000000    0.666667       0.666667
# 21  17.000000    7.333333    16.433333   0.666667    0.333333       0.333333
# 22  15.666667    6.000000    15.433333   0.666667    0.333333       0.333333
# 23  11.666667    3.666667    12.366667   0.333333    0.000000       0.000000
# 25  12.333333    4.000000    13.166667   0.333333    0.000000       0.000000
#
# [128 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 14 2023-11-27  20:00  Premier League  Matchweek 13
#                         15 2023-12-02  15:00  Premier League  Matchweek 14
#                         16 2023-12-05  19:30  Premier League  Matchweek 15
#                         17 2023-12-09  15:00  Premier League  Matchweek 16
#                         18 2023-12-17  14:00  Premier League  Matchweek 17
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 14  Mon  Away      L  2.0  3.0           Fulham  ...
#                         15  Sat  Away      L  1.0  2.0          Arsenal  ...
#                         16  Tue  Home      W  1.0  0.0          Burnley  ...
#                         17  Sat  Home      D  1.0  1.0  Nott'ham Forest  ...
#                         18  Sun  Away      L  0.0  3.0         West Ham  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 6          6       1    2.000000    1.333333
#                         7          5       0    1.666667    1.666667
#                         9          6       0    1.000000    1.666667
#                         11         6       1    0.666667    1.000000
#                         13         6       0    0.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 14         0       0    1.666667    1.666667
#                         15         5       0    1.666667    2.000000
#                         16         1       1    1.666667    2.000000
#                         17         5       0    1.333333    1.666667
#                         18         6       0    1.000000    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 6    8.000000    3.666667    14.633333   0.666667
#                         7    5.666667    3.666667    15.366667   0.000000
#                         9    7.000000    3.666667    16.566667   0.666667
#                         11   9.666667    4.000000    16.566667   1.000000
#                         13   9.666667    2.666667    19.333333   1.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 14  12.666667    4.333333    17.733333   0.666667
#                         15  12.000000    4.000000    17.533333   0.333333
#                         16  10.666667    4.000000    15.300000   0.000000
#                         17   7.333333    4.000000    14.400000   0.333333
#                         18   7.666667    3.666667    13.933333   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 6     0.000000       0.000000
#                         7     0.000000       0.000000
#                         9     0.000000       0.000000
#                         11    0.000000       0.000000
#                         13    0.333333       0.333333
# ...                                ...            ...
# Wolverhampton Wanderers 14    0.000000       0.000000
#                         15    0.333333       0.333333
#                         16    0.333333       0.333333
#                         17    0.333333       0.333333
#                         18    0.000000       0.000000
#
# [2541 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

combined, error = make_predictions(matches_rolling, predictors + new_cols)

error
# Out:
# 0.5767195767195767

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

combined.head(10)
# Out:
#     actual  predicted       date     team         opponent result
# 89       0          1 2023-01-03  Arsenal    Newcastle Utd      D
# 90       1          0 2023-01-15  Arsenal        Tottenham      W
# 91       1          0 2023-01-22  Arsenal   Manchester Utd      W
# 92       0          1 2023-02-04  Arsenal          Everton      L
# 93       0          1 2023-02-11  Arsenal        Brentford      D
# 94       0          0 2023-02-15  Arsenal  Manchester City      L
# 95       1          1 2023-02-18  Arsenal      Aston Villa      W
# 96       1          0 2023-02-25  Arsenal   Leicester City      W
# 97       1          0 2023-03-01  Arsenal          Everton      W
# 98       1          1 2023-03-04  Arsenal      Bournemouth      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

combined["new_team"] = combined["team"].map(mapping)

merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2023-01-03                  Arsenal
# 1           1            0 2023-01-15                  Arsenal
# 2           1            0 2023-01-22                  Arsenal
# 3           0            1 2023-02-04                  Arsenal
# 4           0            1 2023-02-11                  Arsenal
# ..        ...          ...        ...                      ...
# 703         0            0 2023-11-27  Wolverhampton Wanderers
# 704         0            0 2023-12-02  Wolverhampton Wanderers
# 705         1            0 2023-12-05  Wolverhampton Wanderers
# 706         0            1 2023-12-09  Wolverhampton Wanderers
# 707         0            0 2023-12-17  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0      Newcastle Utd        D    Arsenal         0            0
# 1          Tottenham        W    Arsenal         0            0
# 2     Manchester Utd        W    Arsenal         0            1
# 3            Everton        L    Arsenal         1            0
# 4          Brentford        D    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 703           Fulham        L     Wolves         1            0
# 704          Arsenal        L     Wolves         1            1
# 705          Burnley        W     Wolves         0            1
# 706  Nott'ham Forest        D     Wolves         0            0
# 707         West Ham        L     Wolves         1            0
#
#                 team_y opponent_y result_y         new_team_y
# 0     Newcastle United    Arsenal        D      Newcastle Utd
# 1    Tottenham Hotspur    Arsenal        L          Tottenham
# 2    Manchester United    Arsenal        L     Manchester Utd
# 3              Everton    Arsenal        W            Everton
# 4            Brentford    Arsenal        D          Brentford
# ..                 ...        ...      ...                ...
# 703             Fulham     Wolves        W             Fulham
# 704            Arsenal     Wolves        W            Arsenal
# 705            Burnley     Wolves        L            Burnley
# 706  Nottingham Forest     Wolves        D  Nottingham Forest
# 707    West Ham United     Wolves        W           West Ham
#
# [708 rows x 13 columns]
